# %% [markdown]
# ![]("https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg")

# %% [markdown]
# #Am doing my first usecase at Databricks
# 1.This is my first project work to explore in databricks

# %% [markdown]
# $${\color{blue}Mohan Ragunathan}$$

# %% [markdown]
# ![inceptez](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %% [markdown]
# ##**_Inceptez WE47 batch aspirants_**

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics_datalake;

# %%
# %run "/Workspace/Users/mohanragunathan2017@gmail.com/databricks-code-repo/4_child_nb_dataload"

# %%
# %fs ls dbfs:/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv

# %%
# %fs
head dbfs:/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv

# %%
df1=spark.read.csv("/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv",header='True')
df1.show()
display(df1)

# %%
spark.read.csv("/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv").write.saveAsTable("mobile_os_usage_new")

# %%
df1=spark.sql("select * from default.mobile_os_usage")
display(df1)

# %%
def upper(x):
    return x.upper()

# %%
def lower(a):
    return a.lower()

# %%
def sqrt(x):
    return x*x

# %%
print("here pasing above defined function",upper('hello'))

# %%
print("here we are testing lower function",lower('HELLO'))

# %%
print("checking squreroot function values of",sqrt(4))

# %%
# %pip install pandas

# %%
import pandas as pd
df = pd.read_csv("/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv")
display(df)

# %%
# %sh
echo "Magic commands tasks completed"
