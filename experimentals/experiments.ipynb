# %%
# %sql
select * from drugstbl_silverview1;

# %%
df1=spark.read.table("gcp_mysql_fc_wd36.logistics.shipments1")
df2=df1.where("city is null")
df2.write.saveAsTable("workspace.default.target_shipment_table1", mode="append")

# %%
# %sql
select * from workspace.default.target_shipment_table;

# %%
def my_spark_prog():
    df1=spark.read.table("gcp_mysql_fc_wd36.logistics.shipments1")
    df2=df1.where("city is null")
    return df2
#display(my_spark_prog())

# %%
# %sql
select * from lakehousecat.deltadb.drugstbl

# %%
# %sql
--update lakehousecat.deltadb.drugstbl set drugname='aaa' where uniqueid= 2999997
delete from lakehousecat.deltadb.drugstbl where uniqueid= 2999997

# %%
# %sql
select * from catalog1_dropme.default.drugstbl_bronze1 where uniqueid= 2999997

# %%
# %sql
select * from workspace.default.account;

# %% [markdown]
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
CREATE CONNECTION mysql_conn
TYPE JDBC
OPTIONS (
  url 'jdbc:mysql://136.114.39.161:3306/cc_mart',
  user 'devuser',
  password 'Inceptez@123',
  driver 'com.mysql.cj.jdbc.Driver'
);

# %%
# %pip install mysql-connector-python

# %%
jdbc_url = "jdbc:mysql://136.114.39.161:3306/cc_mart"

connection_props = {
    "user": "devuser",
    "password": "Inceptez@123",
    "driver": "com.mysql.cj.jdbc.Driver"
}

df = spark.read.jdbc(
    url=jdbc_url,
    table="orders",
    properties=connection_props
)

df.display()

# %%
# %sql
CREATE OR REPLACE CONNECTION mysql_connectionworking3
TYPE mysql
OPTIONS (
  host '34.71.58.152',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql
CREATE FOREIGN CATALOG gcp_cloud_sql_foregin_catalog1
USING CONNECTION mysql_connectionworking3;

# %%
# %sql
SHOW CONNECTIONS;

# %%
# %sql
DESCRIBE CONNECTION mysql_connectionworking2;

# %%
# %sql
show catalogs

# %%
spark.sql("select * from gcp_cloud_sql_foregin_catalog1.testdb.tbl1").show()
